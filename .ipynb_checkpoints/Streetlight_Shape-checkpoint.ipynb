# %%
import numpy as np
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point, LineString
import matplotlib.pyplot as plt

# %% [markdown]
# There are 102 counties in the State of Illinois.

# %%
# read the illinois state shp data
streetlight_shp = gpd.read_file('Streetlight_Data/Shapefile/179765_Illinois_COVID_19_Phase_4_v2_origin/179765_Illinois_COVID_19_Phase_4_v2_origin.shp')
# streetlight_shp = streetlight_shp.loc[:,('GEOID','geometry')]
# streetlight_shp['centroid'] = streetlight_shp.centroid.to_crs(epsg = 4326)
# streetlight_shp.head()
streetlight_shp
# Out:
#       id        name direction  is_pass  is_bidi  \
# 0      1       ADAMS      None        0        0
# 1    101    LAWRENCE      None        0        0
# 2    103         LEE      None        0        0
# 3    105  LIVINGSTON      None        0        0
# 4    107       LOGAN      None        0        0
# ..   ...         ...       ...      ...      ...
# 97    91    KANKAKEE      None        0        0
# 98    93     KENDALL      None        0        0
# 99    95        KNOX      None        0        0
# 100   97        LAKE      None        0        0
# 101   99     LASALLE      None        0        0
#
#                                               geometry
# 0    POLYGON ((-91.50534 40.20028, -91.49184 40.200...
# 1    POLYGON ((-87.90805 38.85012, -87.88944 38.849...
# 2    POLYGON ((-89.62850 41.90158, -89.60971 41.901...
# 3    POLYGON ((-88.25174 41.11422, -88.25110 41.096...
# 4    POLYGON ((-89.60299 40.32010, -89.60299 40.320...
# ...

# %%
base_map = streetlight_shp.plot(color='white', 
                   edgecolor='black', 
                   alpha = 0.1, 
                   figsize = (10,15))
base_map.axis('off')
# Out:
# (-91.71443352, -87.29429867999998, 36.6930531, 42.785266699999994)
